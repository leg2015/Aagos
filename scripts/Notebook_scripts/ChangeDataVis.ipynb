# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import sys
import argparse as argp

# %%
# Parses command line argument for filepath of data to clean
parser = argp.ArgumentParser(description='Visualize Aagos data.')
parser.add_argument("-f", type=str, required=True, help="filepath to where aagos data is stored. Should be the path into the dir where all run dirs are stored", default="./Data/")
# parser.add_argument("-n", type=int, required=True, help="number of replicates for this run of Aagos")
# parser.add_argument("-glob", type=str, help=" what should the glob pattern for these files look like. Defaults to mutation parsing", default='/m_*/*')
args = parser.parse_args()
# filepath = args.f
filepath = "/Users/leg2015/workspace/Aagos/Data"

# %%
files_to_vis = glob.glob(filepath + '/*.csv')
# files_to_vis
# TODO: add some splitting etc to easily parse files, not today tho

# %%
all_mut_dat = pd.read_csv('/Users/leg2015/workspace/Aagos/Data/Mut_rate_FINAL_CleanedDataStatFit.csv', index_col="update", float_precision="high")
all_mut_dat_rep = pd.read_csv('/Users/leg2015/workspace/Aagos/Data/Mut_rate_FINAL_CleanedDataStatFitRep.csv', index_col="update", float_precision="high")
all_change_dat = pd.read_csv('/Users/leg2015/workspace/Aagos/Data/Change_Rate_Corr_CleanedDataStatFit.csv', index_col="update", float_precision="high")

# %%
max_gen_mut_data = all_mut_dat.loc[49000]
early_gen_mut_data = all_mut_dat.loc[10000]
max_gen_rep_mut_data = all_mut_dat_rep.loc[49000]
early_gen_rep_mut_data = all_mut_dat_rep.loc[10000]
gen1000_mut_data = all_mut_dat.loc[1000]
max_gen_change_data = all_change_dat.loc[49000]
thous_gen_change_data = all_change_dat.loc[1000]

# %%
max_gen_mut_data['max_gene_length'] = max_gen_mut_data.max_Multi_Gene_Sites + max_gen_mut_data.max_Neutral_Sites + max_gen_mut_data.max_One_Gene_Sites
max_gen_mut_data['max_coding_sites'] = max_gen_mut_data.max_Multi_Gene_Sites + max_gen_mut_data.max_One_Gene_Sites
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
early_gen_mut_data['mean_gene_length'] = early_gen_mut_data.mean_Multi_Gene_Sites + early_gen_mut_data.mean_Neutral_Sites + early_gen_mut_data.mean_One_Gene_Sites
early_gen_mut_data['mean_coding_sites'] = early_gen_mut_data.mean_Multi_Gene_Sites + early_gen_mut_data.mean_One_Gene_Sites
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
gen1000_mut_data['max_gene_length'] = gen1000_mut_data.max_Multi_Gene_Sites + gen1000_mut_data.max_Neutral_Sites + gen1000_mut_data.max_One_Gene_Sites
gen1000_mut_data['max_coding_sites'] = gen1000_mut_data.max_Multi_Gene_Sites + gen1000_mut_data.max_One_Gene_Sites
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
max_gen_change_data['max_gene_length'] = max_gen_change_data.max_Multi_Gene_Sites + max_gen_change_data.max_Neutral_Sites + max_gen_change_data.max_One_Gene_Sites
max_gen_change_data['max_coding_sites'] = max_gen_change_data.max_Multi_Gene_Sites + max_gen_change_data.max_One_Gene_Sites
max_gen_change_data
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         change  inferiority  max_Multi_Gene_Sites  max_Neighbor_Genes  \
# update
# 49000       50     0.851882                    27               1.125
# 49000       50     0.854727                    41               1.750
# ...

# %%
max_gen_mut_fitness = max_gen_mut_data.loc[:,[ 'max_fitness', 'c', 'm', 'f', 'replicate']]
max_gen_mut_gene_len = max_gen_mut_data.loc[:, ['max_gene_length', 'c', 'm', 'f', 'replicate']]
max_gen_mut_overlap = max_gen_mut_data.loc[:,[ 'max_Overlap', 'c', 'm', 'f', 'replicate']]
max_gen_mut_coding = max_gen_mut_data.loc[:,[ 'max_coding_sites', 'c', 'm', 'f', 'replicate']]
max_gen_mut_neutral = max_gen_mut_data.loc[:,[ 'max_Neutral_Sites', 'c', 'm', 'f', 'replicate']]
max_gen_mut_neighbor = max_gen_mut_data.loc[:,[ 'max_Neighbor_Genes', 'c', 'm', 'f', 'replicate']]

# %%
early_gen_mut_fitness = early_gen_mut_data.loc[:,[ 'mean_fitness', 'c', 'm', 'f', 'replicate']]
early_gen_mut_gene_len = early_gen_mut_data.loc[:, ['mean_gene_length', 'c', 'm', 'f', 'replicate']]
early_gen_mut_overlap = early_gen_mut_data.loc[:,[ 'mean_Overlap', 'c', 'm', 'f', 'replicate']]
early_gen_mut_coding = early_gen_mut_data.loc[:,[ 'mean_coding_sites', 'c', 'm', 'f', 'replicate']]
early_gen_mut_neutral = early_gen_mut_data.loc[:,[ 'mean_Neutral_Sites', 'c', 'm', 'f', 'replicate']]
early_gen_mut_neighbor = early_gen_mut_data.loc[:,[ 'mean_Neighbor_Genes', 'c', 'm', 'f', 'replicate']]

# %%
gen1000_mut_fitness = gen1000_mut_data.loc[:,[ 'max_fitness', 'c', 'm', 'f', 'replicate']]
gen1000_mut_gene_len = gen1000_mut_data.loc[:, ['max_gene_length', 'c', 'm', 'f', 'replicate']]
gen1000_mut_overlap = gen1000_mut_data.loc[:,[ 'max_Overlap', 'c', 'm', 'f', 'replicate']]
gen1000_mut_coding = gen1000_mut_data.loc[:,[ 'max_coding_sites', 'c', 'm', 'f', 'replicate']]
gen1000_mut_neutral = gen1000_mut_data.loc[:,[ 'max_Neutral_Sites', 'c', 'm', 'f', 'replicate']]
gen1000_mut_neighbor = gen1000_mut_data.loc[:,[ 'max_Neighbor_Genes', 'c', 'm', 'f', 'replicate']]

# %%
max_gen_change_fitness = max_gen_change_data.loc[:,[ 'max_fitness', 'change', 'replicate']]
max_gen_change_gene_len = max_gen_change_data.loc[:, ['max_gene_length', 'change', 'replicate']]
max_gen_change_overlap = max_gen_change_data.loc[:,[ 'max_Overlap', 'change', 'replicate']]
max_gen_change_coding = max_gen_change_data.loc[:,[ 'max_coding_sites', 'change', 'replicate']]
max_gen_change_neutral = max_gen_change_data.loc[:,[ 'max_Neutral_Sites', 'change', 'replicate']]
max_gen_change_neighbor = max_gen_change_data.loc[:,[ 'max_Neighbor_Genes', 'change', 'replicate']]

# %%
# thous_gen_change_data
thous_gen_max_fit = thous_gen_change_data.loc[:,[ 'max_fitness', 'change', 'replicate']]

# %%
# change_facet = sns.FacetGrid(max_gen_change_fitness, col="change")
# change_facet.map_dataframe(sns.boxplot, x="f", y="max_Neighbor_Genes")
# for axis in facet.axes.flat:
#     axis.set_xlabel("f")
# plt.subplots_adjust(top=0.95)
# change_facet.fig.suptitle('Gen 49,000 max gene neighbor') # can also get
# change_facet.savefig("change_max_gen_neighbor.pdf")
# sns.load_dataset(max_gen_change_fitness)
# print(max_gen_change_fitness)
# memes = sns.load_dataset("max_gen_change_fitness")
change_plot = sns.boxplot(y=max_gen_change_data["max_Neighbor_Genes"], x="change", data=max_gen_change_data)
plt.suptitle("gen 49000 max gene neighbor")
plt.savefig("change_corr_max_gen_change_data_max_geneneig.pdf")
# TODO: figure early_gen_neighbor how to save pdfs to figure directory
# also way so don't have to boilerplate would be nice

# %%
facet = sns.FacetGrid(max_gen_neighbor, col="c", row="m",)
facet.map_dataframe(sns.boxplot, x="f", y="max_Neighbor_Genes")
for axis in facet.axes.flat:
    axis.set_xlabel("f")
plt.subplots_adjust(top=0.95)
facet.fig.suptitle('Gen 49,000 max gene neighbor') # can also get
facet.savefig("max_gen_neighbor.pdf")
# TODO: figure early_gen_neighbor how to save pdfs to figure directory
# also way so don't have to boilerplate would be nice

# %%
facet = sns.FacetGrid(max_gen_neighbor, col="c", row="m",)
facet.map_dataframe(sns.boxplot, x="f", y="max_Neighbor_Genes")
for axis in facet.axes.flat:
    axis.set_xlabel("f")
plt.subplots_adjust(top=0.95)
facet.fig.suptitle('Gen 49,000 max gene neighbor') # can also get
facet.savefig("max_gen_neighbor.pdf")
# TODO: figure early_gen_neighbor how to save pdfs to figure directory
# also way so don't have to boilerplate would be nice
