# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import sys
import argparse as argp

# %%
mut_50_dat = pd.read_csv('/Users/leg2015/workspace/Aagos/Data/Mut_Treat_Change_50_CleanedDataRep.csv', index_col="update", float_precision="high")
mut_0_dat = pd.read_csv('/Users/leg2015/workspace/Aagos/Data/Mut_Treat_Change_0_CleanedDataRep.csv', index_col="update", float_precision="high")
change_dat = pd.read_csv('/Users/leg2015/workspace/Aagos/Data/Change_Treat_f_.003_CleanedDataRep.csv', index_col="update", float_precision="high")

# %%
mut_50_dat_32 = pd.read_csv('/Users/leg2015/workspace/Aagos/Data/Mut_Treat_Change_50_N_32_CleanedDataRep.csv', index_col="update", float_precision="high")
mut_0_dat_32 = pd.read_csv('/Users/leg2015/workspace/Aagos/Data/Mut_Treat_Change_0_N_32_CleanedDataRep.csv', index_col="update", float_precision="high")
change_dat_32 = pd.read_csv('/Users/leg2015/workspace/Aagos/Data/Change_Treat_f_.003_N_32_CleanedDataRep.csv', index_col="update", float_precision="high")

# %%
mut_50_dat_64 = pd.read_csv('/Users/leg2015/workspace/Aagos/Data/Mut_Treat_Change_50_N_64_CleanedDataRep.csv', index_col="update", float_precision="high")
mut_0_dat_64 = pd.read_csv('/Users/leg2015/workspace/Aagos/Data/Mut_Treat_Change_0_N_64_CleanedDataRep.csv', index_col="update", float_precision="high")
change_dat_64 = pd.read_csv('/Users/leg2015/workspace/Aagos/Data/Change_Treat_f_.003_N_64_CleanedDataRep.csv', index_col="update", float_precision="high")

# %%
mut_50_dat_16 = pd.read_csv('/Users/leg2015/workspace/Aagos/Data/Mut_Treat_Change_50_N_16_CleanedDataRep.csv', index_col="update", float_precision="high")
mut_0_dat_16 = pd.read_csv('/Users/leg2015/workspace/Aagos/Data/Mut_Treat_Change_0_N_16_CleanedDataRep.csv', index_col="update", float_precision="high")
change_dat_16 = pd.read_csv('/Users/leg2015/workspace/Aagos/Data/Change_Treat_f_.003_N_16_CleanedDataRep.csv', index_col="update", float_precision="high")

# %%
mut_2_dat_16 = pd.read_csv('/Users/leg2015/workspace/Aagos/Data/Mut_Treat_Change_2_N_16_CleanedDataRep.csv', index_col="update", float_precision="high")
mut_2_dat_32 = pd.read_csv('/Users/leg2015/workspace/Aagos/Data/Mut_Treat_Change_2_N_32_CleanedDataRep.csv', index_col="update", float_precision="high")

# %%
mut_20_dat_128 = pd.read_csv('/Users/leg2015/workspace/Aagos/Data/Mut_Treat_Change_20_CleanedDataRep.csv', index_col="update", float_precision="high")

# %%
mut_50_max = mut_50_dat.loc[50000]
mut_0_max = mut_0_dat.loc[50000]
mut_20_max = mut_20_dat_128.loc[50000]
change_max = change_dat.loc[50000]
# change_max

# %%
mut_50_max_64 = mut_50_dat_64.loc[50000]
mut_0_max_64 = mut_0_dat_64.loc[50000]
change_max_64 = change_dat_64.loc[50000]
# change_max

# %%
mut_50_max_32 = mut_50_dat_32.loc[50000]
mut_0_max_32 = mut_0_dat_32.loc[50000]
change_max_32 = change_dat_32.loc[50000]
# change_max

# %%
mut_50_max_16 = mut_50_dat_16.loc[50000]
mut_0_max_16 = mut_0_dat_16.loc[50000]
change_max_16 = change_dat_16.loc[50000]
# change_max

# %%
mut_2_max_16 = mut_2_dat_16.loc[50000]
mut_2_max_32 = mut_2_dat_32.loc[50000]

# %%
mut_0_max['overlap'] = (mut_0_max["one_gene_overlap"] + mut_0_max["two_gene_overlap"] + mut_0_max["three_gene_overlap"] + mut_0_max["four_gene_overlap"] + mut_0_max["five_gene_overlap"] + mut_0_max["six_gene_overlap"] + mut_0_max["seven_gene_overlap"] + mut_0_max["eight_gene_overlap"] + mut_0_max["nine_gene_overlap"] + mut_0_max["ten_gene_overlap"] + mut_0_max["eleven_gene_overlap"] + mut_0_max["twelve_gene_overlap"] + mut_0_max["thirteen_gene_overlap"] + mut_0_max["fourteen_gene_overlap"] + mut_0_max["fifteen_gene_overlap"] + mut_0_max["sixteen_gene_overlap"]) / 17
mut_50_max['overlap'] = (mut_50_max["one_gene_overlap"] + mut_50_max["two_gene_overlap"] + mut_50_max["three_gene_overlap"] + mut_50_max["four_gene_overlap"] + mut_50_max["five_gene_overlap"] + mut_50_max["six_gene_overlap"] + mut_50_max["seven_gene_overlap"] + mut_50_max["eight_gene_overlap"] + mut_50_max["nine_gene_overlap"] + mut_50_max["ten_gene_overlap"] + mut_50_max["eleven_gene_overlap"] + mut_50_max["twelve_gene_overlap"] + mut_50_max["thirteen_gene_overlap"] + mut_50_max["fourteen_gene_overlap"] + mut_50_max["fifteen_gene_overlap"] + mut_50_max["sixteen_gene_overlap"]) / 17
change_max['overlap'] = (change_max["one_gene_overlap"] + change_max["two_gene_overlap"] + change_max["three_gene_overlap"] + change_max["four_gene_overlap"] + change_max["five_gene_overlap"] + change_max["six_gene_overlap"] + change_max["seven_gene_overlap"] + change_max["eight_gene_overlap"] + change_max["nine_gene_overlap"] + change_max["ten_gene_overlap"] + change_max["eleven_gene_overlap"] + change_max["twelve_gene_overlap"] + change_max["thirteen_gene_overlap"] + change_max["fourteen_gene_overlap"] + change_max["fifteen_gene_overlap"] + change_max["sixteen_gene_overlap"]) / 17

mut_50_max_64['overlap'] = (mut_50_max_64["one_gene_overlap"] + mut_50_max_64["two_gene_overlap"] + mut_50_max_64["three_gene_overlap"] + mut_50_max_64["four_gene_overlap"] + mut_50_max_64["five_gene_overlap"] + mut_50_max_64["six_gene_overlap"] + mut_50_max_64["seven_gene_overlap"] + mut_50_max_64["eight_gene_overlap"] + mut_50_max_64["nine_gene_overlap"] + mut_50_max_64["ten_gene_overlap"] + mut_50_max_64["eleven_gene_overlap"] + mut_50_max_64["twelve_gene_overlap"] + mut_50_max_64["thirteen_gene_overlap"] + mut_50_max_64["fourteen_gene_overlap"] + mut_50_max_64["fifteen_gene_overlap"] + mut_50_max_64["sixteen_gene_overlap"]) / 17
mut_0_max_64['overlap'] = (mut_0_max_64["one_gene_overlap"] + mut_0_max_64["two_gene_overlap"] + mut_0_max_64["three_gene_overlap"] + mut_0_max_64["four_gene_overlap"] + mut_0_max_64["five_gene_overlap"] + mut_0_max_64["six_gene_overlap"] + mut_0_max_64["seven_gene_overlap"] + mut_0_max_64["eight_gene_overlap"] + mut_0_max_64["nine_gene_overlap"] + mut_0_max_64["ten_gene_overlap"] + mut_0_max_64["eleven_gene_overlap"] + mut_0_max_64["twelve_gene_overlap"] + mut_0_max_64["thirteen_gene_overlap"] + mut_0_max_64["fourteen_gene_overlap"] + mut_0_max_64["fifteen_gene_overlap"] + mut_0_max_64["sixteen_gene_overlap"]) / 17
change_max_64['overlap'] = (change_max_64["one_gene_overlap"] + change_max_64["two_gene_overlap"] + change_max_64["three_gene_overlap"] + change_max_64["four_gene_overlap"] + change_max_64["five_gene_overlap"] + change_max_64["six_gene_overlap"] + change_max_64["seven_gene_overlap"] + change_max_64["eight_gene_overlap"] + change_max_64["nine_gene_overlap"] + change_max_64["ten_gene_overlap"] + change_max_64["eleven_gene_overlap"] + change_max_64["twelve_gene_overlap"] + change_max_64["thirteen_gene_overlap"] + change_max_64["fourteen_gene_overlap"] + change_max_64["fifteen_gene_overlap"] + change_max_64["sixteen_gene_overlap"]) / 17

mut_50_max_32['overlap'] = (mut_50_max_32["one_gene_overlap"] + mut_50_max_32["two_gene_overlap"] + mut_50_max_32["three_gene_overlap"] + mut_50_max_32["four_gene_overlap"] + mut_50_max_32["five_gene_overlap"] + mut_50_max_32["six_gene_overlap"] + mut_50_max_32["seven_gene_overlap"] + mut_50_max_32["eight_gene_overlap"] + mut_50_max_32["nine_gene_overlap"] + mut_50_max_32["ten_gene_overlap"] + mut_50_max_32["eleven_gene_overlap"] + mut_50_max_32["twelve_gene_overlap"] + mut_50_max_32["thirteen_gene_overlap"] + mut_50_max_32["fourteen_gene_overlap"] + mut_50_max_32["fifteen_gene_overlap"] + mut_50_max_32["sixteen_gene_overlap"]) / 17
mut_0_max_32['overlap'] = (mut_0_max_32["one_gene_overlap"] + mut_0_max_32["two_gene_overlap"] + mut_0_max_32["three_gene_overlap"] + mut_0_max_32["four_gene_overlap"] + mut_0_max_32["five_gene_overlap"] + mut_0_max_32["six_gene_overlap"] + mut_0_max_32["seven_gene_overlap"] + mut_0_max_32["eight_gene_overlap"] + mut_0_max_32["nine_gene_overlap"] + mut_0_max_32["ten_gene_overlap"] + mut_0_max_32["eleven_gene_overlap"] + mut_0_max_32["twelve_gene_overlap"] + mut_0_max_32["thirteen_gene_overlap"] + mut_0_max_32["fourteen_gene_overlap"] + mut_0_max_32["fifteen_gene_overlap"] + mut_0_max_32["sixteen_gene_overlap"]) / 17
change_max_32['overlap'] = (change_max_32["one_gene_overlap"] + change_max_32["two_gene_overlap"] + change_max_32["three_gene_overlap"] + change_max_32["four_gene_overlap"] + change_max_32["five_gene_overlap"] + change_max_32["six_gene_overlap"] + change_max_32["seven_gene_overlap"] + change_max_32["eight_gene_overlap"] + change_max_32["nine_gene_overlap"] + change_max_32["ten_gene_overlap"] + change_max_32["eleven_gene_overlap"] + change_max_32["twelve_gene_overlap"] + change_max_32["thirteen_gene_overlap"] + change_max_32["fourteen_gene_overlap"] + change_max_32["fifteen_gene_overlap"] + change_max_32["sixteen_gene_overlap"]) / 17

mut_50_max_16['overlap'] = (mut_50_max_16["one_gene_overlap"] + mut_50_max_16["two_gene_overlap"] + mut_50_max_16["three_gene_overlap"] + mut_50_max_16["four_gene_overlap"] + mut_50_max_16["five_gene_overlap"] + mut_50_max_16["six_gene_overlap"] + mut_50_max_16["seven_gene_overlap"] + mut_50_max_16["eight_gene_overlap"] + mut_50_max_16["nine_gene_overlap"] + mut_50_max_16["ten_gene_overlap"] + mut_50_max_16["eleven_gene_overlap"] + mut_50_max_16["twelve_gene_overlap"] + mut_50_max_16["thirteen_gene_overlap"] + mut_50_max_16["fourteen_gene_overlap"] + mut_50_max_16["fifteen_gene_overlap"] + mut_50_max_16["sixteen_gene_overlap"]) / 17
mut_0_max_16['overlap'] = (mut_0_max_16["one_gene_overlap"] + mut_0_max_16["two_gene_overlap"] + mut_0_max_16["three_gene_overlap"] + mut_0_max_16["four_gene_overlap"] + mut_0_max_16["five_gene_overlap"] + mut_0_max_16["six_gene_overlap"] + mut_0_max_16["seven_gene_overlap"] + mut_0_max_16["eight_gene_overlap"] + mut_0_max_16["nine_gene_overlap"] + mut_0_max_16["ten_gene_overlap"] + mut_0_max_16["eleven_gene_overlap"] + mut_0_max_16["twelve_gene_overlap"] + mut_0_max_16["thirteen_gene_overlap"] + mut_0_max_16["fourteen_gene_overlap"] + mut_0_max_16["fifteen_gene_overlap"] + mut_0_max_16["sixteen_gene_overlap"]) / 17
change_max_16['overlap'] = (change_max_16["one_gene_overlap"] + change_max_16["two_gene_overlap"] + change_max_16["three_gene_overlap"] + change_max_16["four_gene_overlap"] + change_max_16["five_gene_overlap"] + change_max_16["six_gene_overlap"] + change_max_16["seven_gene_overlap"] + change_max_16["eight_gene_overlap"] + change_max_16["nine_gene_overlap"] + change_max_16["ten_gene_overlap"] + change_max_16["eleven_gene_overlap"] + change_max_16["twelve_gene_overlap"] + change_max_16["thirteen_gene_overlap"] + change_max_16["fourteen_gene_overlap"] + change_max_16["fifteen_gene_overlap"] + change_max_16["sixteen_gene_overlap"]) / 17

mut_2_max_16['overlap'] = (mut_2_max_16["one_gene_overlap"] + mut_2_max_16["two_gene_overlap"] + mut_2_max_16["three_gene_overlap"] + mut_2_max_16["four_gene_overlap"] + mut_2_max_16["five_gene_overlap"] + mut_2_max_16["six_gene_overlap"] + mut_2_max_16["seven_gene_overlap"] + mut_2_max_16["eight_gene_overlap"] + mut_2_max_16["nine_gene_overlap"] + mut_2_max_16["ten_gene_overlap"] + mut_2_max_16["eleven_gene_overlap"] + mut_2_max_16["twelve_gene_overlap"] + mut_2_max_16["thirteen_gene_overlap"] + mut_2_max_16["fourteen_gene_overlap"] + mut_2_max_16["fifteen_gene_overlap"] + mut_2_max_16["sixteen_gene_overlap"]) / 17
mut_2_max_32['overlap'] = (mut_2_max_32["one_gene_overlap"] + mut_2_max_32["two_gene_overlap"] + mut_2_max_32["three_gene_overlap"] + mut_2_max_32["four_gene_overlap"] + mut_2_max_32["five_gene_overlap"] + mut_2_max_32["six_gene_overlap"] + mut_2_max_32["seven_gene_overlap"] + mut_2_max_32["eight_gene_overlap"] + mut_2_max_32["nine_gene_overlap"] + mut_2_max_32["ten_gene_overlap"] + mut_2_max_32["eleven_gene_overlap"] + mut_2_max_32["twelve_gene_overlap"] + mut_2_max_32["thirteen_gene_overlap"] + mut_2_max_32["fourteen_gene_overlap"] + mut_2_max_32["fifteen_gene_overlap"] + mut_2_max_32["sixteen_gene_overlap"]) / 17

mut_20_max['overlap'] = (mut_20_max["one_gene_overlap"] + mut_20_max["two_gene_overlap"] + mut_20_max["three_gene_overlap"] + mut_20_max["four_gene_overlap"] + mut_20_max["five_gene_overlap"] + mut_20_max["six_gene_overlap"] + mut_20_max["seven_gene_overlap"] + mut_20_max["eight_gene_overlap"] + mut_20_max["nine_gene_overlap"] + mut_20_max["ten_gene_overlap"] + mut_20_max["eleven_gene_overlap"] + mut_20_max["twelve_gene_overlap"] + mut_20_max["thirteen_gene_overlap"] + mut_20_max["fourteen_gene_overlap"] + mut_20_max["fifteen_gene_overlap"] + mut_20_max["sixteen_gene_overlap"]) / 17
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
mut_0_max['change'] = 0
mut_50_max['change'] = 50
mut_0_max_32['change'] = 0
mut_50_max_32['change'] = 50
mut_0_max_64['change'] = 0
mut_50_max_64['change'] = 50
mut_0_max_16['change'] = 0
mut_50_max_16['change'] = 50
mut_20_max['change'] = 20
mut_2_max_16['change'] = 2
mut_2_max_32['change'] = 2
mut_tot = pd.concat([mut_0_max, mut_50_max], axis=0)
mut_tot_64 = pd.concat([mut_0_max_64, mut_50_max_64], axis=0)
mut_tot_32 = pd.concat([mut_0_max_32, mut_50_max_32], axis=0)
mut_tot_16 = pd.concat([mut_0_max_16, mut_50_max_16], axis=0)
mut_to_low_change_16 = pd.concat([mut_0_max_16, mut_50_max_16], axis=0)
mut_to_low_change_32 = pd.concat([mut_0_max_16, mut_50_max_16], axis=0)
mut_tot_ch_20_128 = pd.concat([mut_0_max, mut_20_max], axis=0)
mut_tot_ch_2_16 = pd.concat([mut_0_max, mut_2_max_16], axis=0)
mut_tot_ch_2_32 = pd.concat([mut_0_max, mut_2_max_32], axis=0)
# mut_tot
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
print(change_max.columns)
print(len(change_max.index))
# Out:
# Index(['zero_gene_overlap', 'one_gene_overlap', 'two_gene_overlap',
#        'three_gene_overlap', 'four_gene_overlap', 'five_gene_overlap',
#        'six_gene_overlap', 'seven_gene_overlap', 'eight_gene_overlap',
#        'nine_gene_overlap', 'ten_gene_overlap', 'eleven_gene_overlap',
#        'twelve_gene_overlap', 'thirteen_gene_overlap', 'fourteen_gene_overlap',
#        'fifteen_gene_overlap', 'sixteen_gene_overlap', 'gene_starts',
#        'coding_sites', 'genome_length', 'fitness', 'gene_neighbors',
#        'replicate', 'change', 'overlap'],
#       dtype='object')
# 1200

# %%
ch_mut_fit_0_plot = sns.boxplot(y=mut_0_max["fitness"], x="f", data=mut_0_max)
plt.suptitle("Bit Flip Mutation Rate on Fitness of Best Organism of N=128 at Gen. 50,000")
plt.savefig("ch_mut_0_N_128_fitness.pdf")

# %%
ch_mut_64_fit_0_plot = sns.boxplot(y=mut_0_max_64["fitness"], x="f", data=mut_0_max_64)
plt.suptitle("Bit Flip Mutation Rate on Fitness of Best Organism of N=64 at Gen. 50,000")
plt.savefig("ch_mut_0_N_64_fitness.pdf")

# %%
ch_mut_32_fit_0_plot = sns.boxplot(y=mut_0_max_32["fitness"], x="f", data=mut_0_max_32)
plt.suptitle("Bit Flip Mutation Rate on Fitness of Best Organism of N=32 at Gen. 50,000")
plt.savefig("ch_mut_0_N_32_fitness.pdf")

# %%
ch_mut_16_fit_0_plot = sns.boxplot(y=mut_0_max_16["fitness"], x="f", data=mut_0_max_16)
plt.suptitle("Bit Flip Mutation Rate on Fitness of Best Organism of N=16 at Gen. 50,000")
plt.savefig("ch_mut_0_N_16_fitness.pdf")

# %%
ch_mut_cod_0_plot = sns.boxplot(y=mut_0_max["coding_sites"], x="f", data=mut_0_max)
plt.suptitle("Bit Flip Mutation Rate on Coding Sites of Best Organism with N=128 at Gen. 50,000")
plt.savefig("ch_mut_0_N_128_change.pdf")

# %%
ch_mut_cod_0_64_plot = sns.boxplot(y=mut_0_max_64["coding_sites"], x="f", data=mut_0_max_64)
plt.suptitle("Bit Flip Mutation Rate on Coding Sites of Best Organism with N=64 at Gen. 50,000")
plt.savefig("ch_mut_0_N_64_change.pdf")

# %%
ch_mut_cod_0_32_plot = sns.boxplot(y=mut_0_max_32["coding_sites"], x="f", data=mut_0_max_32)
plt.suptitle("Bit Flip Mutation Rate on Coding Sites of Best Organism with N=32 at Gen. 50,000")
plt.savefig("ch_mut_0_N_32_change.pdf")

# %%
ch_mut_cod_0_16_plot = sns.boxplot(y=mut_0_max_16["coding_sites"], x="f", data=mut_0_max_16)
plt.suptitle("Bit Flip Mutation Rate on Coding Sites of Best Organism with N=16 at Gen. 50,000")
plt.savefig("ch_mut_0_N_16_change.pdf")

# %%
ch_env_fit_plot = sns.boxplot(y=change_max["fitness"], x="change", data=change_max)
plt.suptitle("Changing Environment Rate on Fitness of Best Organism at Gen. 50,000")
plt.savefig("ch_env_128_fitness.pdf")

# %%
ch_env_fit_64_plot = sns.boxplot(y=change_max_64["fitness"], x="change", data=change_max_64)
plt.suptitle("Changing Environment Rate on Fitness of Best Organism with N=64 at Gen. 50,000")
plt.savefig("ch_env_64_fitness.pdf")

# %%
ch_env_fit_32_plot = sns.boxplot(y=change_max_32["fitness"], x="change", data=change_max_32)
plt.suptitle("Changing Environment Rate on Fitness of Best Organism with N=32 at Gen. 50,000")
plt.savefig("ch_env_32_fitness.pdf")

# %%
ch_env_fit_16_plot = sns.boxplot(y=change_max_16["fitness"], x="change", data=change_max_16)
plt.suptitle("Changing Environment Rate on Fitness of Best Organism with N=16 at Gen. 50,000")
plt.savefig("ch_env_16_fitness.pdf")

# %%
ch_env_64_cod_plot = sns.boxplot(y=change_max_64["coding_sites"], x="change", data=change_max_64)
plt.suptitle("Changing Environment Rate on Number of Coding Sites of Best Organism with N=64 at Gen. 50,000")
plt.savefig("ch_env_64_coding.pdf")

# %%
ch_env_32_cod_plot = sns.boxplot(y=change_max_32["coding_sites"], x="change", data=change_max_32)
plt.suptitle("Changing Environment Rate on Number of Coding Sites of Best Organism with N=32 at Gen. 50,000")
plt.savefig("ch_env_32_coding.pdf")

# %%
ch_env_cod_plot = sns.boxplot(y=change_max["coding_sites"], x="change", data=change_max)
plt.suptitle("Changing Environment Rate on Number of Coding Sites of Best Organism with N=128 at Gen. 50,000")
plt.savefig("ch_env_128_coding.pdf")

# %%
ch_env_cod_plot = sns.boxplot(y=change_max_16["coding_sites"], x="change", data=change_max_16)
plt.suptitle("Changing Environment Rate on Number of Coding Sites of Best Organism with N=16 at Gen. 50,000")
plt.savefig("ch_env_16_coding.pdf")

# %%
ch_mut_fit_both_plot = sns.boxplot(y=mut_tot["fitness"], x="f", hue="change", data=mut_tot)
plt.suptitle("Changing Environment on Fitness of Best Organism with N=128 at Gen. 50,000")
plt.savefig("ch_mut_both_128_fitness.pdf")

# %%
ch_mut_fit_both_plot = sns.boxplot(y=mut_tot_ch_20_128["fitness"], x="f", hue="change", data=mut_tot_ch_20_128)
plt.suptitle("Changing Environment on Fitness of Best Organism with N=128 at Gen. 50,000")
plt.savefig("ch_mut_both_ch_20_128_fitness.pdf")

# %%
ch_mut_fit_both_64_plot = sns.boxplot(y=mut_tot_64["fitness"], x="f", hue="change", data=mut_tot_64)
plt.suptitle("Changing Environment on Fitness of Best Organism with N=64 at Gen. 50,000")
plt.savefig("ch_mut_both_64_fitness.pdf")

# %%
ch_mut_fit_both_32_plot = sns.boxplot(y=mut_tot_32["fitness"], x="f", hue="change", data=mut_tot_32)
plt.suptitle("Changing Environment on Fitness of Best Organism with N=32 at Gen. 50,000")
plt.savefig("ch_mut_both_32_fitness.pdf")

# %%
ch_mut_fit_both_16_plot = sns.boxplot(y=mut_tot_16["fitness"], x="f", hue="change", data=mut_tot_16)
plt.suptitle("Changing Environment on Fitness of Best Organism with N=16 at Gen. 50,000")
plt.savefig("ch_mut_both_16_fitness.pdf")

# %%
ch_mut_fit_both_2_16_plot = sns.boxplot(y=mut_tot_ch_2_16["fitness"], x="f", hue="change", data=mut_tot_ch_2_16)
plt.suptitle("Changing Environment on Fitness of Best Organism with N=16 at Gen. 50,000")
plt.savefig("ch_mut_both_2_16_fitness.pdf")

# %%
ch_mut_fit_both_2_32_plot = sns.boxplot(y=mut_tot_ch_2_32["fitness"], x="f", hue="change", data=mut_tot_ch_2_32)
plt.suptitle("Changing Environment on Fitness of Best Organism with N=32 at Gen. 50,000")
plt.savefig("ch_mut_both_2_32_fitness.pdf")

# %%
ch_mut_cod_both_plot = sns.boxplot(y=mut_tot["coding_sites"], x="f", hue="change", data=mut_tot)
plt.suptitle("Changing Environment on Coding Sites of Best Organism at Gen. 50,000")
plt.savefig("ch_mut_both_128_change.pdf")

# %%
ch_mut_cod_both_plot = sns.boxplot(y=mut_tot_ch_20_128["coding_sites"], x="f", hue="change", data=mut_tot_ch_20_128)
plt.suptitle("Changing Environment on Coding Sites of Best Organism at Gen. 50,000")
plt.savefig("ch_mut_both_ch_20_128_change.pdf")

# %%
ch_mut_cod_both_64_plot = sns.boxplot(y=mut_tot_64["coding_sites"], x="f", hue="change", data=mut_tot_64)
plt.suptitle("Changing Environment on Coding Sites of Best Organism with N=64 at Gen. 50,000")
plt.savefig("ch_mut_both_64_change.pdf")

# %%
# mut_tot_32

# %%
ch_mut_cod_both_32_plot = sns.boxplot(y=mut_tot_32["coding_sites"], x="f", hue="change", data=mut_tot_32)
plt.suptitle("Changing Environment on Coding Sites of Best Organism with N=32 at Gen. 50,000")
plt.savefig("ch_mut_both_32_change.pdf")

# %%
ch_mut_cod_both_16_plot = sns.boxplot(y=mut_tot_16["coding_sites"], x="f", hue="change", data=mut_tot_16)
plt.suptitle("Changing Environment on Coding Sites of Best Organism with N=16 at Gen. 50,000")
plt.savefig("ch_mut_both_16_change.pdf")
